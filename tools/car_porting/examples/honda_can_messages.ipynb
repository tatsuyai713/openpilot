# %%
from opendbc.car import structs
from opendbc.car.honda.values import CAR

TEST_PLATFORMS = set(CAR)

print(f"Test set contains {len(TEST_PLATFORMS)} qualifying platforms:")
for platform in TEST_PLATFORMS:
  print(f"{platform}")
# Out:
# Test set contains 23 qualifying platforms:
# HONDA_PILOT
# HONDA_CIVIC_2022
# HONDA_FREED
# HONDA_ODYSSEY_CHN
# HONDA_CRV
# HONDA_ODYSSEY
# HONDA_HRV
# HONDA_CRV_EU
# ACURA_ILX
# ACURA_RDX_3G
# HONDA_CIVIC_BOSCH_DIESEL
# HONDA_FIT
# HONDA_HRV_3G
# HONDA_INSIGHT
# HONDA_CRV_HYBRID
# HONDA_CIVIC_BOSCH
# ACURA_RDX
# HONDA_PILOT_4G
# HONDA_ACCORD
# HONDA_CRV_5G
# HONDA_E
# HONDA_RIDGELINE
# HONDA_CIVIC

# %%
import random

from openpilot.tools.lib.logreader import LogReader
from openpilot.tools.lib.comma_car_segments import get_comma_car_segments_database

database = get_comma_car_segments_database()
TEST_SEGMENTS = []

MAX_SEGS_PER_PLATFORM = 100  # TODO: Increase this to search more segments

print("Collecting segments from commaCarSegments dataset:\n")
for platform in TEST_PLATFORMS:
  # assert(platform in database)
  if platform not in database:
    print(f"Skipping platform: {platform}, no data available")
    continue
  
  all_segments = database[platform]

  NUM_SEGMENTS = min(len(all_segments), MAX_SEGS_PER_PLATFORM)

  print(f"Got {len(all_segments)} segments for platform {platform}, sampling {NUM_SEGMENTS} segments")

  segment_subset = random.sample(all_segments, NUM_SEGMENTS)
  for segment in segment_subset:
    TEST_SEGMENTS.append([platform, segment])

print(f"\nSampled {len(TEST_SEGMENTS)} segments from commaCarSegments")

# For new car port development, not yet upstream
EXTRA_SEGMENTS = [
  ["ACURA_MDX_4G", "f9c43864cf057d05|2024-01-15--23-01-20/0"],  # CAN-FD
  ["ACURA_INTEGRA", "3f8ae015ce70365f/00000003--a22590d0e4/0"],
  ["HONDA_CITY", "56b2cf1dacdcd033/00000048--3267801001/0"],
  # ["HONDA_ODYSSEY_5G_MMR", "558ac87ada6a88cd/00000036--7d59e2af08/0"],  # no rlogs
  ["ACURA_MDX_4G_MMR", "ad9840558640c31d/0000001a--d6cd4871c2/0"],  # CAN-FD
  ["ACURA_RDX_3G_MMR", "0416c2843c0bfc91/0000001d--59c7744d87/0"],
  ["HONDA_NBOX", "414af83891dbf72c/00000006--51fa6d99cd/0"],
]

TEST_SEGMENTS.extend(EXTRA_SEGMENTS)

print(f"Added {len(EXTRA_SEGMENTS)} manual segments")
# Out:
# Collecting segments from commaCarSegments dataset:
#
# Got 3239 segments for platform HONDA_PILOT, sampling 100 segments
# Got 1341 segments for platform HONDA_CIVIC_2022, sampling 100 segments
# Got 50 segments for platform HONDA_FREED, sampling 50 segments
# Skipping platform: HONDA_ODYSSEY_CHN, no data available
# Got 156 segments for platform HONDA_CRV, sampling 100 segments
# Got 19 segments for platform HONDA_ODYSSEY, sampling 19 segments
# Got 150 segments for platform HONDA_HRV, sampling 100 segments
# Skipping platform: HONDA_CRV_EU, no data available
# Got 4 segments for platform ACURA_ILX, sampling 4 segments
# Got 747 segments for platform ACURA_RDX_3G, sampling 100 segments
# Skipping platform: HONDA_CIVIC_BOSCH_DIESEL, no data available
# Got 282 segments for platform HONDA_FIT, sampling 100 segments
# Got 60 segments for platform HONDA_HRV_3G, sampling 60 segments
# Got 661 segments for platform HONDA_INSIGHT, sampling 100 segments
# Got 359 segments for platform HONDA_CRV_HYBRID, sampling 100 segments
# Got 12 segments for platform HONDA_CIVIC_BOSCH, sampling 12 segments
# Got 147 segments for platform ACURA_RDX, sampling 100 segments
# Got 2 segments for platform HONDA_PILOT_4G, sampling 2 segments
# Got 16 segments for platform HONDA_ACCORD, sampling 16 segments
# Got 3836 segments for platform HONDA_CRV_5G, sampling 100 segments
# Got 2 segments for platform HONDA_E, sampling 2 segments
# Got 50 segments for platform HONDA_RIDGELINE, sampling 50 segments
# Got 1483 segments for platform HONDA_CIVIC, sampling 100 segments
#
# Sampled 1315 segments from commaCarSegments
# Added 6 manual segments

# %%
import copy
from math import isclose
import matplotlib.pyplot as plt
import numpy as np

from opendbc.can.parser import CANParser
from opendbc.car.honda.values import DBC
from opendbc.car.honda.hondacan import CanBus

from openpilot.selfdrive.pandad import can_capnp_to_list
from openpilot.tools.lib.logreader import LogReader

door_address = 1029
position_addresses = [392, 401, 419]
mt_address = 477
all_addresses = [*position_addresses, mt_address, door_address]
buses = [0, 1]

car_results = {}
for segment in TEST_SEGMENTS:
  car_results[segment[0]] = {}
  for address in all_addresses:
    car_results[segment[0]][address] = 0

for segment in TEST_SEGMENTS:
  print(f"Analyzing segment {segment[1]:<44} for {segment[0]}")
  lr = LogReader(segment[1])
  CP = lr.first("carParams")
  if CP is None:
    continue


  segment_counts = {}
  gear_activity = {}
  for address in all_addresses:
    segment_counts[address] = 0
    gear_activity[address] = False
    
  can_msgs = [msg for msg in lr if msg.which() == "can"]
  for can_msg in can_msgs:
    for packet in can_msg.can:
      for address in all_addresses:
        if packet.src in buses and packet.address == address:
          if address == 392:
            assert len(packet.dat) == 6
            segment_counts[392] += 1
            if packet.dat[0] & 0x7F != 0:
              gear_activity[address] = True
          if address == 401:
            assert len(packet.dat) == 8
            segment_counts[401] += 1
            if packet.dat[3] & 0xF != 0:
              gear_activity[address] = True
          if address == 419:
            assert len(packet.dat) == 8
            segment_counts[419] += 1
            if packet.dat[3] & 0x7F != 0:
              gear_activity[address] = True
          if address == 477:
            # Only used for MT, but often present on non-MT cars, not as easy to detect gear activity
            assert len(packet.dat) == 8
            segment_counts[477] += 1
          if address == 1029:
            assert len(packet.dat) == 8
            segment_counts[1029] += 1

  # Make sure gear position activity was found, or the MT message is present
  print(segment_counts)
    
  gear_position_found = False
  for address in position_addresses:
    if segment_counts[address] > 0:
      frequency = round(segment_counts[address] / 60)
      if gear_activity[address]:
        print(f"Found shifter position: GEARBOX_{address} at {frequency}Hz")
        assert(address == 392 and isclose(frequency, 100, abs_tol=20) or \
               address == 401 and isclose(frequency, 100, abs_tol=20) or \
               address == 419 and isclose(frequency, 50, abs_tol=10))               
        car_results[segment[0]][address] += 1
        gear_position_found = True

  if not gear_position_found:
    address = mt_address
    frequency = round(segment_counts[address] / 60)
    print(f"Found manual trans car: GEARBOX_477 at {frequency}Hz")
    assert isclose(frequency, 50, abs_tol=5)
    car_results[segment[0]][address] += 1

  if segment_counts[door_address] > 0:
    frequency = round(segment_counts[door_address] / 60)
    print(f"Found door message: DOORS_OPEN at {frequency}Hz")
    assert isclose(frequency, 3, abs_tol=1)
    car_results[segment[0]][door_address] += 1

print(f"Analysis finished")
# Out:
# Analyzing segment c31ea510a692b5c3/000000eb--0d78ddcfe0/5/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9dae484044b3cfe8/000003e6--79f1b775d3/15/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 50b9db073fd0ea07/000005d1--1be0173955/27/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 6868a58803419504/00000023--cbeeef8a29/3/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9098b6df85df4bab/00000115--f3134c11a7/63/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 11bfdda7cffeb882/00000431--c2e526977a/1/s    for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment ad1b9150af890d9e/000001cd--e69da9c086/36/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9098b6df85df4bab/0000011b--fd63d35256/7/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 2f46ad8f2394b80f/000001ed--35414ef6d1/17/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3ea5fd848e391728/0000023d--cb4b483fb9/37/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9ba4bba4d44a94e5/00000016--0b42ddffc4/9/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment fd1b73324838a949/0000025f--7a2ad2db7a/39/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 859cfb7352fa2786/000005d7--ff6a64e225/4/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3001, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment c7ee58d25a6bdddc/0000000a--c4e6c94998/48/s   for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3001, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9dae484044b3cfe8/000003cc--70fa144a4a/17/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3f4d8c6e1329405c/0000046b--631f7166a1/24/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3001, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment e06c4b84b4ca7964/00000090--a211d790d0/17/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 5b400951a7ca1c0b/00000006--e2470d60c2/23/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment c31ea510a692b5c3/0000022d--0739ac6f9e/49/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment adc4a7c670779ee7/0000000d--cd29041d13/63/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9bac7575fac62395/000005be--8fd7efdaba/7/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 5b400951a7ca1c0b/0000001e--56f44b9496/48/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8a9bfee29c5a277a/00000100--8569a098a4/4/s    for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment e06c4b84b4ca7964/00000083--7af0019c23/50/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 669abc0816f7d879/00000009--91719d0c59/18/s   for HONDA_PILOT
# {392: 6005, 401: 0, 419: 3003, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 33414660dc3cf77c/0000068c--383f8cc116/17/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b168dde5f920d11a/000003cb--ca6a94ac7a/7/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment d5da0ec987b03a6b/000000a0--3809c50bb2/3/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3f4d8c6e1329405c/00000438--b45fe68ecf/20/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 50b9db073fd0ea07/0000046b--7451c88b46/12/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3e062aad81256fe9/00000002--96878d649e/2/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment a7f52f253cc2f654/00000527--6420a8fb10/6/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9a9cb04589fe5e56/00000003--01e92952b5/9/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 76146c287d5bc5ed/000002e0--8c698526dd/13/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 11bfdda7cffeb882/00000582--8437fdf63b/2/s    for HONDA_PILOT
# {392: 5999, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3e062aad81256fe9/00000004--f86242271d/10/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3001, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment c31ea510a692b5c3/0000023b--28294d7448/46/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 43799248fe2b14c4/00000087--92f418be51/6/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3ea5fd848e391728/000001dc--6a5b26c2da/30/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 6a50c87482bea213/000004d7--dc82ea9964/7/s    for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1b096ee882b315b7/000001ae--14a1ab3c8a/6/s    for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3001, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1b096ee882b315b7/00000155--223d34c8d8/38/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 669abc0816f7d879/00000002--3fae787ca4/21/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 21e8d07ec53def2a/00000656--a7564137bb/22/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3001, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b168dde5f920d11a/0000035a--54f9a27b90/16/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment fff9af2c280cebe7/000003df--f5b9484545/20/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment d473adb8f636df14/0000003e--f0afcd98cf/22/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment fc883bd6fe459212/00000363--56e3711cda/15/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment c31ea510a692b5c3/000001f8--c523a4595f/15/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9bac7575fac62395/000007a1--ea8184bafd/0/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3065, 477: 0, 1029: 204}
# Found shifter position: GEARBOX_419 at 51Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9ba4bba4d44a94e5/00000010--347f8933a2/8/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment c7ee58d25a6bdddc/0000000c--476dfbd303/19/s   for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3001, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 47cf1e910d7c6935/00000350--b8ae42f02d/153/s  for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3f4d8c6e1329405c/00000447--9e45920e28/11/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 216172f653b1fb30/00000043--88b565d89c/2/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment d473adb8f636df14/0000003e--f0afcd98cf/18/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment fd1b73324838a949/000002cc--ef7d2b3c5d/2/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 6795ded7f9db1720/00000464--dbe51045f8/3/s    for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 5094d702d742ab31/00000140--055954028c/8/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1b096ee882b315b7/00000194--0d1bd90825/22/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 0ece3917a1e2f698/00000490--9f5913a29b/30/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 21e8d07ec53def2a/0000068c--b0aa0e791d/27/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment dbe0000d590476c8/00000208--0bcd11a745/60/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 55ec112106850c4c/000000de--c841587fe5/44/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 216172f653b1fb30/00000058--5c04cd5c2a/8/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8f2bfbb36d26effd/00000339--e36e21e987/11/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 0ece3917a1e2f698/000003fb--fff08ea272/4/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8a9bfee29c5a277a/00000100--8569a098a4/41/s   for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 059c8352ab54bf9b/000004da--7918c34ed6/40/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment fff9af2c280cebe7/0000036a--0a314d342e/7/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment adc4a7c670779ee7/0000006f--e2b6da1290/9/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 33414660dc3cf77c/000006c6--979199317b/16/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 67667ae7f86e0cd6/00000002--fa7b35698d/2/s    for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment f35d3a10f0b3d5e8/00000025--0512c9e022/58/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 812b2084c6bdfe4c/000002a4--cc0570ae73/96/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 47cf1e910d7c6935/00000346--e8ffe69689/186/s  for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 76146c287d5bc5ed/0000037c--6c19cbfbd5/103/s  for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3ea5fd848e391728/00000229--813a7d24bc/2/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 695826b02fd8fe16/00000275--8cec820551/4/s    for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 669abc0816f7d879/0000000f--7516b7de8c/21/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9098b6df85df4bab/00000115--f3134c11a7/54/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 6a50c87482bea213/000004a2--ea378a478a/65/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 354636699a744ca5/00000130--7bb856d5db/30/s   for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b168dde5f920d11a/00000394--1bb4708b77/3/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3f4d8c6e1329405c/00000447--9e45920e28/88/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9098b6df85df4bab/0000012b--44748f5ad1/8/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3001, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 6868a58803419504/00000042--03a6c4cf16/21/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 9a9cb04589fe5e56/00000004--4d2bf86cf7/7/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment c7ee58d25a6bdddc/0000000b--9a17c56fb3/4/s    for HONDA_PILOT
# {392: 6000, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 5b400951a7ca1c0b/00000030--c242300786/4/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment be1abe624ed13c3a/00000005--68295441ba/6/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 669abc0816f7d879/00000002--3fae787ca4/36/s   for HONDA_PILOT
# {392: 6001, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_392 at 100Hz
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment dbe0000d590476c8/000002a8--ba459722a3/17/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 059c8352ab54bf9b/0000061d--e645f689ff/10/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 11bfdda7cffeb882/0000055b--ee90592615/2/s    for HONDA_PILOT
# {392: 5713, 401: 0, 419: 2856, 477: 0, 1029: 189}
# Found shifter position: GEARBOX_392 at 95Hz
# Found shifter position: GEARBOX_419 at 48Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b168dde5f920d11a/00000039--fe755ee620/21/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment c31ea510a692b5c3/0000022a--774ce36c05/22/s   for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment da7d4c7c00a25e08/00000044--749ca7e6e0/110/s  for HONDA_PILOT
# {392: 0, 401: 0, 419: 2999, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8f2bfbb36d26effd/0000040d--304b633563/135/s  for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 693042edc45b2c27/00000004--ea6fe9a78e/6/s    for HONDA_PILOT
# {392: 0, 401: 0, 419: 3000, 477: 0, 1029: 199}
# Found shifter position: GEARBOX_419 at 50Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment fdeff4955d072b7e/00000064--bd1781e18d/10/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 2999, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 858feae53f7053c3/00000024--f5e830fa45/16/s   for HONDA_CIVIC_2022
# {392: 0, 401: 6000, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 9175dc9e26114811/000001c7--db47cc6736/76/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment ff4e9b4cbcc038e0/00000216--860d6fcf51/13/s   for HONDA_CIVIC_2022
# {392: 0, 401: 6000, 419: 0, 477: 3001, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 6e12554fbd20d6d1/0000094a--2172d838ba/11/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 251122482046c71b/0000041e--2d56c63426/38/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 9175dc9e26114811/0000019e--59eac9f7a6/59/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 4d4cdf94242eb4cf/00000015--4de48998d6/7/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 2999, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 01240ed7dee0d95c/00000003--4a1c0dc971/7/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 31665ca4a96cec42/00000000--a0f3f82203/1/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 367cc983f41236b4/00000000--85f7036d49/4/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 63d289c9b8af52b6/00000033--bf038642d4/23/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 4454b68f636ce6e0/00000000--1efc974c1e/13/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 4454b68f636ce6e0/00000103--28cd401395/0/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3066, 477: 3066, 1029: 0}
# Found shifter position: GEARBOX_419 at 51Hz
# Analyzing segment 9ebedac9dc7ce652/0000006e--fd2f1b52ed/33/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment b9061e8008239ddd/00000007--29221ad845/14/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment ff4e9b4cbcc038e0/0000024e--3ad05ab943/32/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 5e777eb56efe2f7b/000002de--5959487a3c/8/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 6e12554fbd20d6d1/0000095f--272af6f339/133/s  for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 731e8ea4aac81a21/000000b2--b761545849/3/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3001, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment d7542a5726d86699/0000002f--d3904193f5/2/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 858feae53f7053c3/00000049--05a70b2fd4/33/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 251122482046c71b/00000426--bdad93ebc4/24/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5997, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 29196d7bbc6483d5/00000015--f613e4a872/13/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 0, 477: 3000, 1029: 0}
# Found manual trans car: GEARBOX_477 at 50Hz
# Analyzing segment 6e12554fbd20d6d1/00000a73--8b1204ff7b/21/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment ad1133116ff5bdb7/00000002--3b0d9b8485/4/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 29196d7bbc6483d5/00000015--f613e4a872/58/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 0, 477: 3001, 1029: 0}
# Found manual trans car: GEARBOX_477 at 50Hz
# Analyzing segment b9061e8008239ddd/00000007--29221ad845/21/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment fc4d8f4e5f8b353a/00000529--462189145e/14/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 367cc983f41236b4/0000000b--d291858c60/2/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 6e7fb7b2a248a493/0000000a--7f0dcc2c22/3/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment fc4d8f4e5f8b353a/000004e3--cbf3224e64/34/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment ad1133116ff5bdb7/00000002--3b0d9b8485/2/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 4454b68f636ce6e0/00000188--39e39d7d75/230/s  for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 2999, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 63d289c9b8af52b6/00000008--b9151bc856/7/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 2999, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 6e12554fbd20d6d1/00000913--f05b772bef/14/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 56522a314f738219/00000031--f34e266d8d/12/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 4d7c1e8e3c928514/00000004--fac6490447/1/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment a1754212c8c11495/00000001--63dddf0f4f/2/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 367cc983f41236b4/0000000a--204701d215/9/s    for HONDA_CIVIC_2022
# {392: 0, 401: 6000, 419: 0, 477: 3001, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 5e777eb56efe2f7b/00000288--c3cc2544d0/7/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 5e777eb56efe2f7b/00000341--41a01c2819/8/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 29196d7bbc6483d5/00000015--f613e4a872/24/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 0, 477: 3000, 1029: 0}
# Found manual trans car: GEARBOX_477 at 50Hz
# Analyzing segment 01240ed7dee0d95c/00000012--49173301e6/23/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 4f0380c0cb3220d9/00000001--402b5db4c3/24/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 29196d7bbc6483d5/00000015--f613e4a872/3/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 0, 477: 3000, 1029: 0}
# Found manual trans car: GEARBOX_477 at 50Hz
# Analyzing segment fc4d8f4e5f8b353a/0000053c--263ce3dac1/16/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment b9061e8008239ddd/00000007--29221ad845/17/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 63d289c9b8af52b6/00000033--bf038642d4/21/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment d07eb85a1260e543/000000f7--8c3e7c3aca/78/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 858feae53f7053c3/00000023--d611f53528/9/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment b9061e8008239ddd/00000007--29221ad845/9/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 485e3501abcacc80/00000000--a7547e3318/3/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 01240ed7dee0d95c/00000000--f5e5c939c0/0/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3075, 477: 3075, 1029: 0}
# Found shifter position: GEARBOX_419 at 51Hz
# Analyzing segment d7542a5726d86699/00000030--58a5c6f318/16/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 24ed642977047bc8/0000002f--864b7c4a47/29/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment ad1133116ff5bdb7/00000002--3b0d9b8485/10/s   for HONDA_CIVIC_2022
# {392: 0, 401: 6000, 419: 0, 477: 3001, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment f867075f9e920047/00000001--e2bcf8ca4e/0/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3073, 477: 3073, 1029: 0}
# Found shifter position: GEARBOX_419 at 51Hz
# Analyzing segment 4d7c1e8e3c928514/0000009a--c8b5bfb5f5/4/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment fc4d8f4e5f8b353a/000005a4--7dd725dc3a/2/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 4d7c1e8e3c928514/0000000c--f0de52e8cd/33/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 24ed642977047bc8/0000002d--1249ff301b/17/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 9ebedac9dc7ce652/00000094--4fd01808af/5/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 9234e42d985d483a/00000012--300e5dcab8/91/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 56522a314f738219/00000006--4d548cf381/20/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment fc4d8f4e5f8b353a/0000054a--bf8e9efdd8/2/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 251122482046c71b/00000425--ec4af468bb/16/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 24ed642977047bc8/00000016--ff56ff0d1a/1/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 4d4cdf94242eb4cf/00000014--f3df57ce9d/6/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 5e777eb56efe2f7b/00000289--c2e6996288/15/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment f867075f9e920047/00000000--12bb29292e/9/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3001, 477: 3001, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 29196d7bbc6483d5/00000015--f613e4a872/70/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 0, 477: 3000, 1029: 0}
# Found manual trans car: GEARBOX_477 at 50Hz
# Analyzing segment 9ebedac9dc7ce652/000000a1--9e640fea35/16/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 9175dc9e26114811/00000213--b61b91f451/33/s   for HONDA_CIVIC_2022
# {392: 0, 401: 6000, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment d313e54d1691a342/00000099--3b7b0de7af/21/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 4a27bfb2c9db9fc6/00000596--eadc587eb1/112/s  for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 0bb821a24d4f1f47/00000000--0a74cb304c/1/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment d313e54d1691a342/00000098--f7bd3c3228/16/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3001, 477: 3001, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 570343e389176edb/00000002--7745641593/5/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 29196d7bbc6483d5/00000015--f613e4a872/18/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 0, 477: 3000, 1029: 0}
# Found manual trans car: GEARBOX_477 at 50Hz
# Analyzing segment 4d7c1e8e3c928514/00000035--4ba422ea9d/28/s   for HONDA_CIVIC_2022
# {392: 0, 401: 6000, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 0dacabc563f7e7d7/0000045f--742f880977/14/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 6e7fb7b2a248a493/0000007b--29270747fe/65/s   for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 4d4cdf94242eb4cf/00000014--f3df57ce9d/5/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 24ed642977047bc8/00000006--f4d78ad423/8/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 4f0380c0cb3220d9/00000001--402b5db4c3/18/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 251122482046c71b/00000425--ec4af468bb/10/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment fc4d8f4e5f8b353a/0000054c--00e0621d4f/25/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5996, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment b9061e8008239ddd/00000007--29221ad845/11/s   for HONDA_CIVIC_2022
# {392: 0, 401: 6000, 419: 0, 477: 3001, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 251122482046c71b/00000417--9a3e1142fd/39/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 9175dc9e26114811/00000233--951ecfa7bc/72/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 24ed642977047bc8/00000003--770003257a/1/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment d7542a5726d86699/0000002f--d3904193f5/3/s    for HONDA_CIVIC_2022
# {392: 0, 401: 5998, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment ff4e9b4cbcc038e0/0000023d--0c51bfc7a7/18/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 4454b68f636ce6e0/0000002f--a046307a79/6/s    for HONDA_CIVIC_2022
# {392: 0, 401: 0, 419: 3000, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment ad1133116ff5bdb7/00000002--3b0d9b8485/0/s    for HONDA_CIVIC_2022
# {392: 0, 401: 6148, 419: 0, 477: 3077, 1029: 0}
# Found shifter position: GEARBOX_401 at 102Hz
# Analyzing segment 4d7c1e8e3c928514/000000af--8553cc467a/33/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 6e12554fbd20d6d1/00000a29--d4cbf36dc3/38/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 2999, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 56522a314f738219/0000002f--ac64378abb/26/s   for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 9175dc9e26114811/00000241--40a5916ef7/113/s  for HONDA_CIVIC_2022
# {392: 0, 401: 5999, 419: 0, 477: 3000, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000647--b62d3376f5/4/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005db--ed0f252c31/35/s   for HONDA_FREED
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000520--965092919b/97/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000534--009a1bcd18/89/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000635--9459786d89/22/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000658--4729a2bfe0/9/s    for HONDA_FREED
# {392: 0, 401: 6002, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000647--b62d3376f5/9/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000645--bc3bd0f562/9/s    for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/0000060d--8946079a85/7/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000534--009a1bcd18/96/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/0000065f--cee09e1df3/1/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005b2--07a46b45a7/4/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/0000065f--cee09e1df3/10/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005b8--6ec767ffa5/59/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/0000066a--c4197b7e19/4/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000658--4729a2bfe0/11/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000661--2aacf99618/11/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000609--82b85c5500/5/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000637--7203e40a60/5/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005b1--e3f5980158/21/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000534--009a1bcd18/83/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000520--965092919b/86/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000568--d315c5af5f/10/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000517--a701b97c45/8/s    for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000647--b62d3376f5/17/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005c0--bdf9625907/7/s    for HONDA_FREED
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000648--796df66483/49/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000534--009a1bcd18/71/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/0000055a--9a89ef00a1/30/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000543--f2eaed8f73/19/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005da--eb868c15c3/38/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000520--965092919b/38/s   for HONDA_FREED
# {392: 0, 401: 6002, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000553--f979198269/3/s    for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/0000054b--827c162375/34/s   for HONDA_FREED
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000534--009a1bcd18/86/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/0000063d--4adc3b478f/15/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000612--9580277db1/7/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005c0--bdf9625907/5/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005fb--8e5899c431/7/s    for HONDA_FREED
# {392: 0, 401: 6002, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000520--965092919b/25/s   for HONDA_FREED
# {392: 0, 401: 5997, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005c0--bdf9625907/16/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005d3--dd338aef4b/11/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000609--82b85c5500/14/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000534--009a1bcd18/139/s  for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005da--eb868c15c3/15/s   for HONDA_FREED
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005da--eb868c15c3/20/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000520--965092919b/44/s   for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/00000659--519d7871fe/30/s   for HONDA_FREED
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005d4--deaea2328e/1/s    for HONDA_FREED
# {392: 0, 401: 6001, 419: 0, 477: 0, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analyzing segment 38d0b7ab68b64338/000005f2--fb615c5c77/13/s   for HONDA_FREED
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 0}
# ...
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 901e20a9811b61ab/00000005--79169b5c3e/18/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 201}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 242b33685ed4e03a/0000022f--f1536ad26c/3/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 39563a18fe07169f/00000050--70922ad337/4/s    for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7e06d432a43eca85/00000176--be9927958a/20/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 43799248fe2b14c4/0000008b--da212027ae/2/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 242b33685ed4e03a/000001fe--9a27efd336/10/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 52534ebb0e145937/00000001--f647452aa4/137/s  for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8d80c16a8485aaf3/00000438--9e2ea8e9fb/5/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7e06d432a43eca85/00000176--be9927958a/30/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3e1e2b62f3f2ac3d/000005b9--d8e1f0d202/12/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 29c365ba7d91f32f/0000092c--11c3c9a138/35/s   for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 39563a18fe07169f/00000003--f850b5267c/3/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment cb722faaaacb6509/0000005d--a7adc7fa5a/49/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 43799248fe2b14c4/00000091--e3b847c78c/12/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 22a0ad68fe420dad/00000040--e9c61ae9fe/14/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8ec2ddeaa6d60d69/00000323--e34e241e08/12/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 4eb7fa5351f3906a/00000255--b2d4c052f0/6/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 870f264b7df72bed/0000041b--09bd645997/9/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 3c91b051965bc34d/0000043b--c43b8b7f48/9/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 4e7d62b08743d633/0000040d--92b2125078/2/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 39563a18fe07169f/00000018--d1861515c7/7/s    for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 901e20a9811b61ab/00000015--b50f13f37f/10/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8d80c16a8485aaf3/000003c8--c4a34b92ba/10/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 22a0ad68fe420dad/00000040--e9c61ae9fe/16/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 2afae89623d6ae9c/00000510--c1934a68e3/18/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 22a0ad68fe420dad/00000058--3a09059141/4/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment ca351c85d82c5793/00000071--c2a939a8fb/94/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8ec2ddeaa6d60d69/00000317--38a5ff79c8/10/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7e06d432a43eca85/00000176--be9927958a/25/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1514ea48b7d2b371/000000a0--088b85159f/36/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 53f9420a47414f17/0000030d--4eda77d267/15/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b029c0f4cf2064e7/000000bd--5d4667460b/35/s   for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 901e20a9811b61ab/00000016--f804443ef3/1/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8ec2ddeaa6d60d69/000002fe--5637d4c764/4/s    for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 242b33685ed4e03a/000001fe--9a27efd336/2/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b029c0f4cf2064e7/00000058--c0c92ae37f/4/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 0945b6c6b3ebaa9f/00000063--95c3f1c3c5/5/s    for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 4ba246fcf95a8716/0000012f--f2c422e8a7/7/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7e06d432a43eca85/00000142--2e78946bc4/15/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b029c0f4cf2064e7/00000062--9bf2845558/0/s    for HONDA_CIVIC
# {392: 0, 401: 6308, 419: 0, 477: 0, 1029: 211}
# Found shifter position: GEARBOX_401 at 105Hz
# Found door message: DOORS_OPEN at 4Hz
# Analyzing segment b029c0f4cf2064e7/00000451--b84d284627/8/s    for HONDA_CIVIC
# {392: 0, 401: 5997, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 29c365ba7d91f32f/000007d7--788f53b951/72/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 22a0ad68fe420dad/00000040--e9c61ae9fe/10/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 22a0ad68fe420dad/0000002e--1875d6e042/29/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 0945b6c6b3ebaa9f/000000eb--e216b67846/10/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7528525a29a9d9e6/00000567--aac7da244b/14/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b029c0f4cf2064e7/00000062--9bf2845558/18/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 4eb7fa5351f3906a/000001c9--a36fe82ff3/20/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment ca351c85d82c5793/0000009e--7b9ebf9dee/3/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8ec2ddeaa6d60d69/0000031d--2ea1339e8c/21/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 242b33685ed4e03a/00000236--80c156f91c/24/s   for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment cb722faaaacb6509/0000005f--c546adf9f0/60/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7528525a29a9d9e6/000004c1--b4dd59e72b/4/s    for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment d7cd27c4a1159c3d/00000413--57f2a44241/85/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1514ea48b7d2b371/00000100--31182c8afa/38/s   for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b029c0f4cf2064e7/0000045b--c40c73da25/23/s   for HONDA_CIVIC
# {392: 0, 401: 6000, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment b029c0f4cf2064e7/00000073--3d70a29f8f/13/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7e06d432a43eca85/0000011d--be19314117/5/s    for HONDA_CIVIC
# {392: 0, 401: 5997, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment cb722faaaacb6509/0000005d--a7adc7fa5a/37/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 0945b6c6b3ebaa9f/000000c5--1c292bea13/58/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 7e06d432a43eca85/00000146--a32d6bb486/12/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1650b727edeac35a/0000002a--66c6427764/24/s   for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1650b727edeac35a/00000008--78b82594a2/13/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 52534ebb0e145937/00000001--f647452aa4/103/s  for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 4ba246fcf95a8716/00000168--29c8683887/1/s    for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1650b727edeac35a/0000000d--dc07950f2f/42/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 1514ea48b7d2b371/000000a8--ffab913231/13/s   for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 0945b6c6b3ebaa9f/00000112--963a0175a9/46/s   for HONDA_CIVIC
# {392: 0, 401: 5997, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 870f264b7df72bed/00000487--a233104f5e/5/s    for HONDA_CIVIC
# {392: 0, 401: 5999, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 8d80c16a8485aaf3/0000036c--9febe1852e/1/s    for HONDA_CIVIC
# {392: 0, 401: 5998, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment 4ba246fcf95a8716/00000109--89b0b07bf9/16/s   for HONDA_CIVIC
# {392: 0, 401: 5997, 419: 0, 477: 0, 1029: 200}
# Found shifter position: GEARBOX_401 at 100Hz
# Found door message: DOORS_OPEN at 3Hz
# Analyzing segment f9c43864cf057d05|2024-01-15--23-01-20/0      for ACURA_MDX_4G
# {392: 0, 401: 0, 419: 3076, 477: 3076, 1029: 0}
# Found shifter position: GEARBOX_419 at 51Hz
# Analyzing segment 3f8ae015ce70365f/00000003--a22590d0e4/0      for ACURA_INTEGRA
# {392: 0, 401: 6113, 419: 0, 477: 3057, 1029: 0}
# Found shifter position: GEARBOX_401 at 102Hz
# Analyzing segment 56b2cf1dacdcd033/00000048--3267801001/0      for HONDA_CITY
# {392: 0, 401: 6130, 419: 0, 477: 3064, 1029: 0}
# Found shifter position: GEARBOX_401 at 102Hz
# Analyzing segment ad9840558640c31d/0000001a--d6cd4871c2/0      for ACURA_MDX_4G_MMR
# {392: 0, 401: 0, 419: 3067, 477: 3068, 1029: 0}
# Found shifter position: GEARBOX_419 at 51Hz
# Analyzing segment 0416c2843c0bfc91/0000001d--59c7744d87/0      for ACURA_RDX_3G_MMR
# {392: 0, 401: 0, 419: 2970, 477: 2970, 1029: 0}
# Found shifter position: GEARBOX_419 at 50Hz
# Analyzing segment 414af83891dbf72c/00000006--51fa6d99cd/0      for HONDA_NBOX
# {392: 0, 401: 5971, 419: 0, 477: 2986, 1029: 0}
# Found shifter position: GEARBOX_401 at 100Hz
# Analysis finished

# %%
print(f"Gear messages by platform      0x188 0x191 0x1A3 0x1DD 0x405")
print(f"------------------------------ ----- ----- ----- ----- -----")
for platform in sorted(car_results):
  print(f"{platform:30} {car_results[platform][392]:5} {car_results[platform][401]:5} {car_results[platform][419]:5} {car_results[platform][477]:5} {car_results[platform][1029]:5}")
# Out:
# Gear messages by platform      0x188 0x191 0x1A3 0x1DD 0x405
# ------------------------------ ----- ----- ----- ----- -----
# ACURA_ILX                          0     0     4     0     4
# ACURA_INTEGRA                      0     1     0     0     0
# ACURA_MDX_4G                       0     0     1     0     0
# ACURA_MDX_4G_MMR                   0     0     1     0     0
# ACURA_RDX                        100     0     0     0   100
# ACURA_RDX_3G                       0     0   100     0     0
# ACURA_RDX_3G_MMR                   0     0     1     0     0
# HONDA_ACCORD                       0    16     0     0     0
# HONDA_CITY                         0     1     0     0     0
# HONDA_CIVIC                        0   100     0     0   100
# HONDA_CIVIC_2022                   0    72    22     6     0
# HONDA_CIVIC_BOSCH                  0    12     0     0     5
# HONDA_CRV                          0   100     0     0   100
# HONDA_CRV_5G                       0   100     0     0   100
# HONDA_CRV_HYBRID                   0     0   100     0     0
# HONDA_E                            0     0     2     0     0
# HONDA_FIT                          0   100     0     0   100
# HONDA_FREED                        0    50     0     0     0
# HONDA_HRV                          0   100     0     0     0
# HONDA_HRV_3G                       0    60     0     0     0
# HONDA_INSIGHT                      0     0   100     0   100
# HONDA_NBOX                         0     1     0     0     0
# HONDA_ODYSSEY                      0     0    19     0    19
# HONDA_PILOT                       23     0   100     0   100
# HONDA_PILOT_4G                     0     0     2     0     0
# HONDA_RIDGELINE                    0     0    50     0    50
